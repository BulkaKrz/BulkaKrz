# %% [markdown]
# <a href="https://colab.research.google.com/github/BulkaKrz/BulkaKrz/blob/main/seaborn_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
df = sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.regplot(data = df, x='total_bill', y='tip')

# %% [markdown]
# ***
# ### HEATMAP

# %%
uni = np.random.randn(100, 100)
uni
# Out:
# array([[ 0.22498135,  1.30240367,  1.54369524, ..., -1.30729743,
#         -0.67861781,  0.88494788],
#        [ 0.92705409, -0.33622762, -0.20390519, ..., -0.44383619,
#          0.5769167 ,  0.181124  ],
#        [-0.42172956, -0.82854793,  0.93471805, ...,  0.46881792,
#         -0.64144592,  0.44553911],
#        ...,
#        [-1.67678161, -1.06614506,  0.76999201, ..., -0.76201205,
#          0.83299926, -1.40511557],
#        [-0.9825309 , -0.07288029, -0.14218138, ..., -1.27978718,
#          1.05386025, -1.1219069 ],
#        [ 1.40761409,  0.44102647,  0.00554011, ...,  0.71840786,
#          1.25442479,  0.7249741 ]])

# %%
sns.heatmap(uni)

# %%
df = sns.load_dataset('flights')
df.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
df.describe()
# Out:
#               year  passengers
# count   144.000000  144.000000
# mean   1954.500000  280.298611
# std       3.464102  119.966317
# min    1949.000000  104.000000
# 25%    1951.750000  180.000000
# 50%    1954.500000  265.500000
# 75%    1957.250000  360.500000
# max    1960.000000  622.000000

# %%
df.pivot(index='month', columns='year', values='passengers')
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
df = df.pivot(index='month', columns='year', values='passengers')

# %%
sns.heatmap(df)

# %%
sns.heatmap(df, annot=True)

# %%
sns.set(font_scale=0.8)
sns.heatmap(df, annot=True, fmt='d', cmap='viridis')
